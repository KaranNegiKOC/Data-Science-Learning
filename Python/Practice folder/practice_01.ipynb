# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Hospital_EDA_Practice_Dataset.csv")

# %%
df.head()
# Out:
#   Patient_ID  Age  Gender       City   Department   BMI Smoker  Visits  \
# 0      P0001   58    Male    Chennai   Cardiology  22.2    Yes       5
# 1      P0002   65    Male       Pune      General  18.1    Yes       1
# 2      P0003   30  Female       Pune    Neurology  32.9    Yes       5
# 3      P0004   45  Female     Mumbai  Orthopedics  35.7     No       4
# 4      P0005   24  Female  Hyderabad  Orthopedics  32.8     No       5
#
#    Bill_Amount  Paid_Amount Insured Admission_Date
# 0        50265        50265     Yes     2025-12-13
# 1        17247        17247     Yes     2025-10-15
# 2        51729        51729     Yes     2025-12-24
# 3         8698         8698     Yes     2025-07-14
# 4        37142        37142     Yes     2025-07-13

# %%
df.shape
# Out:
# (300, 12)

# %%
df.tail()
# Out:
#     Patient_ID  Age  Gender       City   Department   BMI Smoker  Visits  \
# 295      P0296   18    Male       Pune  Dermatology  33.7     No       6
# 296      P0297   49  Female  Bengaluru  Orthopedics  27.9    Yes       6
# 297      P0298   66    Male      Delhi   Cardiology  17.8    Yes       8
# 298      P0299   30    Male  Bengaluru  Dermatology  34.1     No       3
# 299      P0300   41    Male       Pune   Cardiology  31.3    Yes       5
#
#      Bill_Amount  Paid_Amount Insured Admission_Date
# 295        16275        14514      No     2025-04-19
# 296        39102        23527      No     2025-12-16
# 297        30920         1022      No     2025-08-08
# 298         8117         3051      No     2025-02-12
# 299        30130        30130     Yes     2025-12-27

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'City', 'Department', 'BMI', 'Smoker',
#        'Visits', 'Bill_Amount', 'Paid_Amount', 'Insured', 'Admission_Date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      300 non-null    object
#  1   Age             300 non-null    int64
#  2   Gender          300 non-null    object
#  3   City            300 non-null    object
#  4   Department      300 non-null    object
#  5   BMI             300 non-null    float64
#  6   Smoker          300 non-null    object
#  7   Visits          300 non-null    int64
#  8   Bill_Amount     300 non-null    int64
#  9   Paid_Amount     300 non-null    int64
#  10  Insured         300 non-null    object
#  11  Admission_Date  300 non-null    object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 28.3+ KB

# %%
df.isnull().sum()
# Out:
# Patient_ID        0
# Age               0
# Gender            0
# City              0
# Department        0
# BMI               0
# Smoker            0
# Visits            0
# Bill_Amount       0
# Paid_Amount       0
# Insured           0
# Admission_Date    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#               Age         BMI      Visits   Bill_Amount   Paid_Amount
# count  300.000000  300.000000  300.000000    300.000000    300.000000
# mean    48.433333   27.727333    4.533333  30193.696667  23161.843333
# std     17.812820    5.409565    2.235819  16295.343153  16692.522161
# min     18.000000   17.500000    1.000000   2340.000000   1022.000000
# 25%     33.000000   23.275000    3.000000  17321.250000   8368.250000
# 50%     47.000000   27.900000    5.000000  30701.500000  18949.000000
# 75%     63.250000   32.625000    6.000000  43151.000000  35512.000000
# max     80.000000   36.500000    8.000000  59728.000000  59728.000000

# %%
cat_cols = df.select_dtypes(include = "object").columns

for col in cat_cols:
    print(f'\nColumn: {col}')
    print(df[col].unique())
# Out:
# Column: Patient_ID
# ['P0001' 'P0002' 'P0003' 'P0004' 'P0005' 'P0006' 'P0007' 'P0008' 'P0009'
#  'P0010' 'P0011' 'P0012' 'P0013' 'P0014' 'P0015' 'P0016' 'P0017' 'P0018'
#  'P0019' 'P0020' 'P0021' 'P0022' 'P0023' 'P0024' 'P0025' 'P0026' 'P0027'
#  'P0028' 'P0029' 'P0030' 'P0031' 'P0032' 'P0033' 'P0034' 'P0035' 'P0036'
#  'P0037' 'P0038' 'P0039' 'P0040' 'P0041' 'P0042' 'P0043' 'P0044' 'P0045'
#  'P0046' 'P0047' 'P0048' 'P0049' 'P0050' 'P0051' 'P0052' 'P0053' 'P0054'
#  'P0055' 'P0056' 'P0057' 'P0058' 'P0059' 'P0060' 'P0061' 'P0062' 'P0063'
#  'P0064' 'P0065' 'P0066' 'P0067' 'P0068' 'P0069' 'P0070' 'P0071' 'P0072'
#  'P0073' 'P0074' 'P0075' 'P0076' 'P0077' 'P0078' 'P0079' 'P0080' 'P0081'
#  'P0082' 'P0083' 'P0084' 'P0085' 'P0086' 'P0087' 'P0088' 'P0089' 'P0090'
#  'P0091' 'P0092' 'P0093' 'P0094' 'P0095' 'P0096' 'P0097' 'P0098' 'P0099'
#  'P0100' 'P0101' 'P0102' 'P0103' 'P0104' 'P0105' 'P0106' 'P0107' 'P0108'
#  'P0109' 'P0110' 'P0111' 'P0112' 'P0113' 'P0114' 'P0115' 'P0116' 'P0117'
# ...

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'City', 'Department', 'BMI', 'Smoker',
#        'Visits', 'Bill_Amount', 'Paid_Amount', 'Insured', 'Admission_Date'],
#       dtype='object')

# %%
num_cols = df.select_dtypes(include = "number").columns

for cols in num_cols:
    plt.figure(figsize = (6,4))
    sns.histplot(df[cols], bins = 20, kde = True)
    plt.title(cols)
    plt.show()

# %%
nums_idx = df.select_dtypes(include = 'number').columns
for nums in nums_idx:
    plt.figure(figsize = (6,4))
    sns.boxplot(x = df[nums])
    plt.title("Bill Amount")
    plt.show()

# %%
cols_obj = df.select_dtypes(include='object').columns
for col in cols_obj:
    plt.figure(figsize = (6,4))
    sns.countplot(x = df[col])
    plt.title(col)
    plt.show()

# %%
plt.figure(figsize = (6,4))
corr = df.corr(numeric_only = True)
sns.heatmap(corr, annot = True)
plt.title("Correlation Heatmap")
plt.show()

# %%
df['Bill_Amount'].mean()
# Out:
# np.float64(30193.696666666667)

# %%
df.head()
# Out:
#   Patient_ID  Age  Gender       City   Department   BMI Smoker  Visits  \
# 0      P0001   58    Male    Chennai   Cardiology  22.2    Yes       5
# 1      P0002   65    Male       Pune      General  18.1    Yes       1
# 2      P0003   30  Female       Pune    Neurology  32.9    Yes       5
# 3      P0004   45  Female     Mumbai  Orthopedics  35.7     No       4
# 4      P0005   24  Female  Hyderabad  Orthopedics  32.8     No       5
#
#    Bill_Amount  Paid_Amount Insured Admission_Date
# 0        50265        50265     Yes     2025-12-13
# 1        17247        17247     Yes     2025-10-15
# 2        51729        51729     Yes     2025-12-24
# 3         8698         8698     Yes     2025-07-14
# 4        37142        37142     Yes     2025-07-13

# %%
df.groupby('Department')['Bill_Amount'].mean()
# Out:
# Department
# Cardiology     25745.490566
# Dermatology    31222.464286
# General        30761.444444
# Neurology      33507.340426
# Orthopedics    28866.224490
# Pediatrics     31578.829268
# Name: Bill_Amount, dtype: float64

# %%
df['Smoker'].value_counts()
# Out:
# Smoker
# Yes    155
# No     145
# Name: count, dtype: int64

# %%
df.groupby('Gender')['BMI'].mean()
# Out:
# Gender
# Female    27.942405
# Male      27.488028
# Name: BMI, dtype: float64

# %%
df['Insured'].value_counts()
# Out:
# Insured
# No     159
# Yes    141
# Name: count, dtype: int64
